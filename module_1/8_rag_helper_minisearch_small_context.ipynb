# %% [markdown]
# # Powerfull RAG
#
# 1. sourece: https://www.youtube.com/watch?v=JxaC6Hrym6c&list=PL3MmuxUbc_hLZFNgSad56pDBKK8KO0XIv&index=10
# 2. select any search instead of minsearch and also ingest_data (call any data)

# %%
# Note: we need to ingest the data everytime, then we use misearch


from ingest import load_faq_data, build_index
from rag_helper import RAGBase


documents = load_faq_data()
index = build_index(documents)

query = "How do I get a certificate?"
assistant = RAGBase(index)
assistant.rag(query)
# Out:
# 'No, you can only get a certificate if you finish the course with a “live” cohort.'
