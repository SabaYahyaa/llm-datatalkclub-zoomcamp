# %% [markdown]
# # Homework module 3

# %% [markdown]
# ## Question 1: Context Engineering
#
# answer: AI Copilot has access to current Kestra plugin documentation

# %% [markdown]
# Try the following experiment:
#
# Open ChatGPT in a private browser window: https://chatgpt.com
# Enter this prompt: "Create a Kestra flow that loads NYC taxi data from CSV to BigQuery"
# Then, use Kestra's AI Copilot with the same prompt
# After trying the same prompt in ChatGPT vs Kestra's AI Copilot, what is the primary reason AI Copilot generates better Kestra flows?
#
# AI Copilot uses a more powerful model
# AI Copilot has access to current Kestra plugin documentation
# AI Copilot uses more tokens
# AI Copilot has internet access

# %% [markdown]
# ## Question 2: RAG vs No RAG
# answer: Vague, generic, or fabricated — the model guesses from training data

# %% [markdown]
# ## Question 3: Token usage — short summary
#
# nearest answer: 60-100 tokens

# %%
📊 Token Usage Summary:
Multilingual Agent:
- Input tokens: 282
- Output tokens: 73
- Total tokens: 355
English Brevity Agent:
- Input tokens: 88
- Output tokens: 41
- Total tokens: 129
💡 Tip: Monitor token usage to understand costs and optimize prompts!

# %% [markdown]
# ## Question 4: Token usage — long summary
#
# answer: 2-5x more

# %%
📊 Token Usage Summary:
Multilingual Agent:
- Input tokens: 282
- Output tokens: 179
- Total tokens: 461
English Brevity Agent:
- Input tokens: 194
- Output tokens: 43
- Total tokens: 237
💡 Tip: Monitor token usage to understand costs and optimize prompts!


so:::  179/73 = 2.452054794520548

# %%
179/73
# Out:
# 2.452054794520548

# %% [markdown]
# ## Question 5: Compare the  3-sentence english_brevity output token count to the original 1-sentence version (also with summary_length = long). How do they compare?
#
# 2-4x more

# %% [markdown]
#  with 3 sentence
# English Brevity Agent:
# - Input tokens: 208
# - Output tokens: 80
# - Total tokens: 288
# 💡 Tip: Monitor token usage to understand costs and optimize prompts!
#
#
# with 1 sentence
# English Brevity Agent:
# - Input tokens: 207
# - Output tokens: 50
# - Total tokens: 257
# 💡 Tip: Monitor token usage to understand costs and optimize prompts!
#
# 80/50

# %% [markdown]
# ## Question 6: for production workflows requiring deterministic, repeatable results with strict compliance requirements (e.g., financial reporting, workflows in highly regulated industries), which approach is most appropriate?
#
# answer: Use traditional task-based workflows for predictability and auditabilit (ETL)
#
# ![image.png](attachment:image.png)
